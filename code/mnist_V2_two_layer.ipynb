# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# 하이퍼파라미터 설정
EPOCHS = 100       ######  epochs에 따른 비교실험 진행 시 변경 (default: 200)
BATCH_SIZE = 128  
VERBOSE = 1
NB_CLASSES = 10   # 분류해야할 클래스의 수
N_HIDDEN = 256  ###### hidden neuron에 따른 비교실험 진행 시 변경 (default: 128)
VALIDATION_SPLIT=0.2 

# 데이터집합 다운로드 (train #: 60000, test #: 10000)
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784
## fully-connected layer의 입력으로 들어갈 수 있게 입력 영상을 일렬로 변경
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train, X_test = X_train / 255.0, X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)

# 모델 빌드
# 2개의 fully-connected layer만으로 구성 (변경 금지)
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
   		input_shape=(RESHAPED,),
   		name='dense_layer', activation='relu'))
model.add(keras.layers.Dense(NB_CLASSES,
   		name='dense_layer_3', activation='softmax'))

model.summary()

# optimizer, loss함수, 평가지표 설정 (변경 금지)
model.compile(optimizer='SGD', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 모델 학습 시작
model.fit(X_train, Y_train,
		batch_size=BATCH_SIZE, epochs=EPOCHS,
		verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

# 모델 저장
model.save("./model/train_two_layer.h5")

# 학습된 모델 평가
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)

predictions = model.predict(X_test)
# Out:
# 60000 train samples
# 10000 test samples
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_layer (Dense)          (None, 256)               200960
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.6699 - accuracy: 0.5325 - val_loss: 0.6950 - val_accuracy: 0.8537
# Epoch 2/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.6633 - accuracy: 0.8453 - val_loss: 0.4806 - val_accuracy: 0.8820
# Epoch 3/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.4933 - accuracy: 0.8738 - val_loss: 0.4072 - val_accuracy: 0.8938
# Epoch 4/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.4240 - accuracy: 0.8870 - val_loss: 0.3691 - val_accuracy: 0.9016
# Epoch 5/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3933 - accuracy: 0.8932 - val_loss: 0.3448 - val_accuracy: 0.9053
# Epoch 6/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3697 - accuracy: 0.8980 - val_loss: 0.3264 - val_accuracy: 0.9101
# Epoch 7/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3458 - accuracy: 0.9033 - val_loss: 0.3132 - val_accuracy: 0.9111
# Epoch 8/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3238 - accuracy: 0.9095 - val_loss: 0.3020 - val_accuracy: 0.9148
# Epoch 9/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3113 - accuracy: 0.9144 - val_loss: 0.2922 - val_accuracy: 0.9178
# Epoch 10/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3091 - accuracy: 0.9133 - val_loss: 0.2835 - val_accuracy: 0.9198
# Epoch 11/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2887 - accuracy: 0.9195 - val_loss: 0.2762 - val_accuracy: 0.9227
# Epoch 12/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2838 - accuracy: 0.9210 - val_loss: 0.2691 - val_accuracy: 0.9249
# Epoch 13/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2817 - accuracy: 0.9227 - val_loss: 0.2628 - val_accuracy: 0.9268
# Epoch 14/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2720 - accuracy: 0.9238 - val_loss: 0.2570 - val_accuracy: 0.9277
# Epoch 15/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2648 - accuracy: 0.9268 - val_loss: 0.2517 - val_accuracy: 0.9296
# Epoch 16/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2614 - accuracy: 0.9278 - val_loss: 0.2467 - val_accuracy: 0.9305
# Epoch 17/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2570 - accuracy: 0.9291 - val_loss: 0.2422 - val_accuracy: 0.9319
# Epoch 18/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2460 - accuracy: 0.9323 - val_loss: 0.2374 - val_accuracy: 0.9332
# Epoch 19/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2412 - accuracy: 0.9335 - val_loss: 0.2332 - val_accuracy: 0.9339
# Epoch 20/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2391 - accuracy: 0.9341 - val_loss: 0.2292 - val_accuracy: 0.9356
# Epoch 21/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2318 - accuracy: 0.9361 - val_loss: 0.2256 - val_accuracy: 0.9367
# Epoch 22/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2352 - accuracy: 0.9358 - val_loss: 0.2220 - val_accuracy: 0.9379
# Epoch 23/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2241 - accuracy: 0.9377 - val_loss: 0.2181 - val_accuracy: 0.9398
# Epoch 24/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2227 - accuracy: 0.9376 - val_loss: 0.2152 - val_accuracy: 0.9408
# Epoch 25/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2249 - accuracy: 0.9374 - val_loss: 0.2119 - val_accuracy: 0.9414
# Epoch 26/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2152 - accuracy: 0.9405 - val_loss: 0.2091 - val_accuracy: 0.9421
# Epoch 27/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2142 - accuracy: 0.9402 - val_loss: 0.2060 - val_accuracy: 0.9433
# Epoch 28/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2048 - accuracy: 0.9426 - val_loss: 0.2033 - val_accuracy: 0.9436
# Epoch 29/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2052 - accuracy: 0.9436 - val_loss: 0.2006 - val_accuracy: 0.9445
# Epoch 30/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2026 - accuracy: 0.9418 - val_loss: 0.1981 - val_accuracy: 0.9452
# Epoch 31/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1989 - accuracy: 0.9450 - val_loss: 0.1954 - val_accuracy: 0.9459
# Epoch 32/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1969 - accuracy: 0.9451 - val_loss: 0.1933 - val_accuracy: 0.9467
# Epoch 33/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1860 - accuracy: 0.9483 - val_loss: 0.1908 - val_accuracy: 0.9477
# Epoch 34/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1861 - accuracy: 0.9472 - val_loss: 0.1883 - val_accuracy: 0.9479
# Epoch 35/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1850 - accuracy: 0.9478 - val_loss: 0.1866 - val_accuracy: 0.9488
# Epoch 36/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1836 - accuracy: 0.9488 - val_loss: 0.1842 - val_accuracy: 0.9496
# Epoch 37/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1733 - accuracy: 0.9514 - val_loss: 0.1819 - val_accuracy: 0.9499
# Epoch 38/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1801 - accuracy: 0.9498 - val_loss: 0.1807 - val_accuracy: 0.9512
# Epoch 39/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1721 - accuracy: 0.9516 - val_loss: 0.1779 - val_accuracy: 0.9516
# Epoch 40/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1705 - accuracy: 0.9528 - val_loss: 0.1762 - val_accuracy: 0.9519
# Epoch 41/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1717 - accuracy: 0.9526 - val_loss: 0.1743 - val_accuracy: 0.9524
# Epoch 42/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1645 - accuracy: 0.9544 - val_loss: 0.1724 - val_accuracy: 0.9530
# Epoch 43/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1628 - accuracy: 0.9552 - val_loss: 0.1707 - val_accuracy: 0.9532
# Epoch 44/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1606 - accuracy: 0.9563 - val_loss: 0.1692 - val_accuracy: 0.9541
# Epoch 45/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1598 - accuracy: 0.9561 - val_loss: 0.1675 - val_accuracy: 0.9549
# Epoch 46/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1566 - accuracy: 0.9568 - val_loss: 0.1659 - val_accuracy: 0.9548
# Epoch 47/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1612 - accuracy: 0.9552 - val_loss: 0.1645 - val_accuracy: 0.9547
# Epoch 48/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1533 - accuracy: 0.9567 - val_loss: 0.1626 - val_accuracy: 0.9559
# Epoch 49/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1510 - accuracy: 0.9591 - val_loss: 0.1615 - val_accuracy: 0.9565
# Epoch 50/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1515 - accuracy: 0.9577 - val_loss: 0.1597 - val_accuracy: 0.9564
# Epoch 51/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1487 - accuracy: 0.9588 - val_loss: 0.1584 - val_accuracy: 0.9563
# Epoch 52/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1452 - accuracy: 0.9606 - val_loss: 0.1570 - val_accuracy: 0.9573
# Epoch 53/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1402 - accuracy: 0.9620 - val_loss: 0.1557 - val_accuracy: 0.9581
# Epoch 54/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1472 - accuracy: 0.9591 - val_loss: 0.1543 - val_accuracy: 0.9577
# Epoch 55/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1387 - accuracy: 0.9615 - val_loss: 0.1531 - val_accuracy: 0.9585
# Epoch 56/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1384 - accuracy: 0.9616 - val_loss: 0.1519 - val_accuracy: 0.9582
# Epoch 57/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1415 - accuracy: 0.9621 - val_loss: 0.1504 - val_accuracy: 0.9588
# Epoch 58/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1372 - accuracy: 0.9615 - val_loss: 0.1494 - val_accuracy: 0.9591
# Epoch 59/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1377 - accuracy: 0.9632 - val_loss: 0.1485 - val_accuracy: 0.9596
# Epoch 60/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1355 - accuracy: 0.9626 - val_loss: 0.1468 - val_accuracy: 0.9597
# Epoch 61/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1294 - accuracy: 0.9650 - val_loss: 0.1460 - val_accuracy: 0.9600
# Epoch 62/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1296 - accuracy: 0.9643 - val_loss: 0.1449 - val_accuracy: 0.9603
# Epoch 63/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1292 - accuracy: 0.9648 - val_loss: 0.1438 - val_accuracy: 0.9601
# Epoch 64/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1308 - accuracy: 0.9642 - val_loss: 0.1428 - val_accuracy: 0.9604
# Epoch 65/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1277 - accuracy: 0.9649 - val_loss: 0.1417 - val_accuracy: 0.9607
# Epoch 66/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1309 - accuracy: 0.9649 - val_loss: 0.1406 - val_accuracy: 0.9610
# Epoch 67/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1274 - accuracy: 0.9646 - val_loss: 0.1397 - val_accuracy: 0.9613
# Epoch 68/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1246 - accuracy: 0.9656 - val_loss: 0.1388 - val_accuracy: 0.9618
# Epoch 69/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1228 - accuracy: 0.9663 - val_loss: 0.1378 - val_accuracy: 0.9621
# Epoch 70/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1156 - accuracy: 0.9679 - val_loss: 0.1370 - val_accuracy: 0.9622
# Epoch 71/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1176 - accuracy: 0.9676 - val_loss: 0.1360 - val_accuracy: 0.9628
# Epoch 72/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1168 - accuracy: 0.9675 - val_loss: 0.1354 - val_accuracy: 0.9625
# Epoch 73/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1188 - accuracy: 0.9670 - val_loss: 0.1346 - val_accuracy: 0.9628
# Epoch 74/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1122 - accuracy: 0.9702 - val_loss: 0.1335 - val_accuracy: 0.9636
# Epoch 75/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1157 - accuracy: 0.9686 - val_loss: 0.1325 - val_accuracy: 0.9636
# Epoch 76/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1128 - accuracy: 0.9695 - val_loss: 0.1320 - val_accuracy: 0.9633
# Epoch 77/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1117 - accuracy: 0.9701 - val_loss: 0.1310 - val_accuracy: 0.9647
# Epoch 78/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1085 - accuracy: 0.9710 - val_loss: 0.1304 - val_accuracy: 0.9647
# Epoch 79/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1102 - accuracy: 0.9714 - val_loss: 0.1293 - val_accuracy: 0.9648
# Epoch 80/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1094 - accuracy: 0.9702 - val_loss: 0.1287 - val_accuracy: 0.9653
# Epoch 81/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1096 - accuracy: 0.9698 - val_loss: 0.1283 - val_accuracy: 0.9647
# Epoch 82/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1060 - accuracy: 0.9724 - val_loss: 0.1271 - val_accuracy: 0.9657
# Epoch 83/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1048 - accuracy: 0.9719 - val_loss: 0.1268 - val_accuracy: 0.9656
# Epoch 84/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1033 - accuracy: 0.9729 - val_loss: 0.1259 - val_accuracy: 0.9661
# Epoch 85/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1014 - accuracy: 0.9733 - val_loss: 0.1254 - val_accuracy: 0.9662
# Epoch 86/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0987 - accuracy: 0.9739 - val_loss: 0.1245 - val_accuracy: 0.9661
# Epoch 87/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1048 - accuracy: 0.9717 - val_loss: 0.1236 - val_accuracy: 0.9664
# Epoch 88/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1024 - accuracy: 0.9734 - val_loss: 0.1230 - val_accuracy: 0.9668
# Epoch 89/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1010 - accuracy: 0.9738 - val_loss: 0.1230 - val_accuracy: 0.9673
# Epoch 90/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0949 - accuracy: 0.9744 - val_loss: 0.1219 - val_accuracy: 0.9670
# Epoch 91/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0976 - accuracy: 0.9742 - val_loss: 0.1213 - val_accuracy: 0.9672
# Epoch 92/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0981 - accuracy: 0.9733 - val_loss: 0.1206 - val_accuracy: 0.9672
# Epoch 93/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1000 - accuracy: 0.9731 - val_loss: 0.1204 - val_accuracy: 0.9674
# Epoch 94/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0987 - accuracy: 0.9730 - val_loss: 0.1196 - val_accuracy: 0.9672
# Epoch 95/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0974 - accuracy: 0.9738 - val_loss: 0.1190 - val_accuracy: 0.9680
# Epoch 96/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0968 - accuracy: 0.9748 - val_loss: 0.1184 - val_accuracy: 0.9683
# Epoch 97/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0942 - accuracy: 0.9762 - val_loss: 0.1182 - val_accuracy: 0.9687
# Epoch 98/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0945 - accuracy: 0.9754 - val_loss: 0.1169 - val_accuracy: 0.9682
# Epoch 99/100
# 375/375 [==============================] - 1s 2ms/step - loss: 0.0921 - accuracy: 0.9758 - val_loss: 0.1166 - val_accuracy: 0.9682
# Epoch 100/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0899 - accuracy: 0.9765 - val_loss: 0.1160 - val_accuracy: 0.9688
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1093 - accuracy: 0.9682
# Test accuracy: 0.9682000279426575
