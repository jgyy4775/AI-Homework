# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras


# 하이퍼파라미터 설정
EPOCHS = 10      ######  epochs에 따른 비교실험 진행 시 변경 (default: 200)
BATCH_SIZE = 128  ## 메모리 오류 발생시 더 작은 값으로 변경 가능 (default: 128)
VERBOSE = 1
NB_CLASSES = 10   # 분류해야할 클래스의 수
N_HIDDEN = 256  ###### hidden neuron에 따른 비교실험 진행 시 변경 (default: 128)
VALIDATION_SPLIT=0.2 

# 데이터집합 다운로드 (train #: 60000, test #: 10000)
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

RESHAPED = 784
## fully-connected layer의 입력으로 들어갈 수 있게 입력 영상을 일렬로 변경
X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train, X_test = X_train / 255.0, X_test / 255.0
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)

# 모델 빌드
# 3개의 fully-connected layer만으로 구성 (변경 금지)
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN,
   		input_shape=(RESHAPED,),
   		name='dense_layer', activation='relu'))
model.add(keras.layers.Dense(N_HIDDEN,
   		name='dense_layer_2', activation='relu'))
model.add(keras.layers.Dense(NB_CLASSES,
   		name='dense_layer_3', activation='softmax'))

model.summary()

# optimizer, loss함수, 평가지표 설정 (변경 금지)
model.compile(optimizer='SGD', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 모델 학습 시작
model.fit(X_train, Y_train,
		batch_size=BATCH_SIZE, epochs=EPOCHS,
		verbose=VERBOSE, validation_split=VALIDATION_SPLIT)

# 모델 저장
model.save("./model/train_three_layer.h5")

# 학습된 모델 평가
test_loss, test_acc = model.evaluate(X_test, Y_test)
print('Test accuracy:', test_acc)

predictions = model.predict(X_test)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 60000 train samples
# 10000 test samples
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_layer (Dense)          (None, 256)               200960
# _________________________________________________________________
# dense_layer_2 (Dense)        (None, 256)               65792
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 10)                2570
# =================================================================
# Total params: 269,322
# Trainable params: 269,322
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 375/375 [==============================] - 4s 4ms/step - loss: 1.8121 - accuracy: 0.5171 - val_loss: 0.6563 - val_accuracy: 0.8570
# Epoch 2/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5995 - accuracy: 0.8570 - val_loss: 0.4191 - val_accuracy: 0.8917
# Epoch 3/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4231 - accuracy: 0.8863 - val_loss: 0.3535 - val_accuracy: 0.9026
# Epoch 4/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3667 - accuracy: 0.9001 - val_loss: 0.3197 - val_accuracy: 0.9105
# Epoch 5/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3340 - accuracy: 0.9074 - val_loss: 0.2972 - val_accuracy: 0.9164
# Epoch 6/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3137 - accuracy: 0.9117 - val_loss: 0.2811 - val_accuracy: 0.9220
# Epoch 7/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2931 - accuracy: 0.9174 - val_loss: 0.2687 - val_accuracy: 0.9249
# Epoch 8/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2763 - accuracy: 0.9214 - val_loss: 0.2563 - val_accuracy: 0.9264
# Epoch 9/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2692 - accuracy: 0.9229 - val_loss: 0.2474 - val_accuracy: 0.9316
# Epoch 10/10
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2544 - accuracy: 0.9281 - val_loss: 0.2384 - val_accuracy: 0.9323
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2388 - accuracy: 0.9318
# Test accuracy: 0.9318000078201294
